# %%
from rdkit import Chem
from rdkit.Chem import Draw

suppl = Chem.SDMolSupplier("outputs2/DiffSBDD_ligands.sdf", sanitize=False, removeHs=False)
mols = [m for m in suppl if m is not None]
img = Draw.MolsToGridImage(mols[:12], molsPerRow=4, subImgSize=(250, 250))
img
