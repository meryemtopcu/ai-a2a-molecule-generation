# %%
# Import required libraries for molecular analysis
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, QED, rdMolDescriptors

# Load SMILES from Pocket2Mol output
smiles_path = "../../outputs/pocket2mol/sample_4eiy_clean.pdb_2026_04_28__12_28_34/SMILES.txt"

with open(smiles_path, "r") as f:
    smiles_list = [line.strip() for line in f.readlines() if line.strip()]

print(f"Total SMILES loaded: {len(smiles_list)}")
print("\nFirst 5 molecules:")
for s in smiles_list[:5]:
    print(s)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       5
#       6 # Load SMILES from Pocket2Mol output
#       7 smiles_path = "../../outputs/pocket2mol/sample_4eiy_clean.pdb_2026_04_28__12_28_34/SMILES.txt"
#       8
# ----> 9 with open(smiles_path, "r") as f:
#      10     smiles_list = [line.strip() for line in f.readlines() if line.strip()]
#      11
#      12 print(f"Total SMILES loaded: {len(smiles_list)}")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../outputs/pocket2mol/sample_4eiy_clean.pdb_2026_04_28__12_28_34/SMILES.txt'
